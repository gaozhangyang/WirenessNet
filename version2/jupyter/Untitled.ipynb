# %%
from tqdm import tqdm_notebook
import numpy as np
import pandas as pd
import scipy.io

# %%
r1=pd.read_csv('../results/result_G-0-1000.csv',index_col=0)
r2=pd.read_csv('../results/result_G-1001-2000.csv',index_col=0)
r3=pd.read_csv('../results/result_G-2001-3000.csv',index_col=0)
r4=pd.read_csv('../results/result_G-3001-4000.csv',index_col=0)
r5=pd.read_csv('../results/result_G-4001-5000.csv',index_col=0)
r6=pd.read_csv('../results/result_G-5001-6000.csv',index_col=0)
r7=pd.read_csv('../results/result_G-6001-7000.csv',index_col=0)
r8=pd.read_csv('../results/result_G-7001-8000.csv',index_col=0)
r9=pd.read_csv('../results/result_G-8001-9000.csv',index_col=0)
r10=pd.read_csv('../results/result_G-9001-9800.csv',index_col=0)

# %%
r=pd.concat([r1,r2,r3,r4,r5,r6,r7,r8,r9,r10])

# %%
r.shape
# Out:
# (9801, 3)

# %%
r
# Out:
#        A    B     max_Delay
# 0      2    2  3.000000e+00
# 1      2    3  9.000000e+00
# 2      2    4  5.000000e+00
# 3      2    5  2.500000e+01
# 4      2    6  7.000000e+00
# 5      2    7  4.900000e+01
# 6      2    8  9.000000e+00
# 7      2    9  8.100000e+01
# 8      2   10  1.100000e+01
# 9      2   11  1.210000e+02
# 10     2   12  1.300000e+01
# 11     2   13  1.690000e+02
# 12     2   14  1.500000e+01
# 13     2   15  2.250000e+02
# 14     2   16  1.700000e+01
# 15     2   17  2.890000e+02
# 16     2   18  1.900000e+01
# 17     2   19  3.610000e+02
# 18     2   20  2.100000e+01
# 19     2   21  4.410000e+02
# 20     2   22  2.300000e+01
# 21     2   23  5.290000e+02
# 22     2   24  2.500000e+01
# 23     2   25  6.250000e+02
# 24     2   26  2.700000e+01
# 25     2   27  7.290000e+02
# 26     2   28  2.900000e+01
# 27     2   29  8.410000e+02
# 28     2   30  3.100000e+01
# 29     2   31  9.610000e+02
# ..   ...  ...           ...
# 770  100   71  1.740000e+04
# ...

# %%
r[r['max_Delay']==np.inf]
# Out:
#        A   B  max_Delay
# 198    4   2        inf
# 594    8   2        inf
# 596    8   4        inf
# 694    9   3        inf
# 697    9   6        inf
# 990   12   2        inf
# 994   12   6        inf
# 385   16   2        inf
# 387   16   4        inf
# 391   16   8        inf
# 395   16  12        inf
# 584   18   3        inf
# 587   18   6        inf
# 593   18  12        inf
# 781   20   2        inf
# 789   20  10        inf
# 177   24   2        inf
# 179   24   4        inf
# 181   24   6        inf
# 187   24  12        inf
# 279   25   5        inf
# 284   25  10        inf
# 289   25  15        inf
# 294   25  20        inf
# 475   27   3        inf
# 478   27   6        inf
# 481   27   9        inf
# 490   27  18        inf
# 573   28   2        inf
# 585   28  14        inf
# ..   ...  ..        ...
# 319   96  16        inf
# 327   96  24        inf
# 339   96  36        inf
# 351   96  48        inf
# 375   96  72        inf
# 508   98   7        inf
# ...

# %%
r.to_csv('../results/all_results.csv')
scipy.io.savemat('../results/all_results.mat',{'r':r.values})
