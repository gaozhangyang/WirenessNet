# %%
from tqdm import tqdm_notebook
import numpy as np
import pandas as pd

# %%
r1=pd.read_csv('../results/result_G-0-1000.csv',index_col=0)
r2=pd.read_csv('../results/result_G-1001-2000.csv',index_col=0)
r3=pd.read_csv('../results/result_G-2001-3000.csv',index_col=0)
r4=pd.read_csv('../results/result_G-3001-4000.csv',index_col=0)
r5=pd.read_csv('../results/result_G-4001-5000.csv',index_col=0)
r6=pd.read_csv('../results/result_G-5001-6000.csv',index_col=0)
r7=pd.read_csv('../results/result_G-6001-7000.csv',index_col=0)
r8=pd.read_csv('../results/result_G-7001-8000.csv',index_col=0)
r9=pd.read_csv('../results/result_G-8001-9000.csv',index_col=0)
r10=pd.read_csv('../results/result_G-9001-9800.csv',index_col=0)

# %%
r=pd.concat([r1,r2,r3,r4,r5,r6,r7,r8,r9,r10])

# %%
r
# Out:
#          A     B     max_Delay
# 0      2.0   2.0  3.000000e+00
# 1      2.0   3.0  9.000000e+00
# 2      2.0   4.0  5.000000e+00
# 3      2.0   5.0  2.500000e+01
# 4      2.0   6.0  7.000000e+00
# 5      2.0   7.0  4.900000e+01
# 6      2.0   8.0  9.000000e+00
# 7      2.0   9.0  8.100000e+01
# 8      2.0  10.0  1.100000e+01
# 9      2.0  11.0  1.210000e+02
# 10     2.0  12.0  1.300000e+01
# 11     2.0  13.0  1.690000e+02
# 12     2.0  14.0  1.500000e+01
# 13     2.0  15.0  2.250000e+02
# 14     2.0  16.0  1.700000e+01
# 15     2.0  17.0  2.890000e+02
# 16     2.0  18.0  1.900000e+01
# 17     2.0  19.0  3.610000e+02
# 18     2.0  20.0  2.100000e+01
# 19     2.0  21.0  4.410000e+02
# 20     2.0  22.0  2.300000e+01
# 21     2.0  23.0  5.290000e+02
# 22     2.0  24.0  2.500000e+01
# 23     2.0  25.0  6.250000e+02
# 24     2.0  26.0  2.700000e+01
# 25     2.0  27.0  7.290000e+02
# 26     2.0  28.0  2.900000e+01
# 27     2.0  29.0  8.410000e+02
# 28     2.0  30.0  3.100000e+01
# 29     2.0  31.0  9.610000e+02
# ..     ...   ...           ...
# 769  100.0  70.0           inf
# 770  100.0  71.0  1.740000e+04
# 771  100.0  72.0  3.020000e+04
# 772  100.0  73.0  9.300000e+03
# 773  100.0  74.0  1.317000e+05
# 774  100.0  75.0  1.860000e+04
# 775  100.0  76.0  1.230000e+04
# 776  100.0  77.0  1.090000e+04
# 777  100.0  78.0  3.680000e+04
# 778  100.0  79.0  1.188000e+05
# 779  100.0  80.0           inf
# 780  100.0  81.0  1.130000e+04
# 781  100.0  82.0  1.700000e+04
# 782  100.0  83.0  2.460000e+04
# 783  100.0  84.0  3.110000e+04
# 784  100.0  85.0  1.220000e+04
# 785  100.0  86.0  2.870000e+04
# 786  100.0  87.0  2.560000e+04
# 787  100.0  88.0  2.340000e+04
# 788  100.0  89.0  7.200000e+04
# 789  100.0  90.0           inf
# 790  100.0  91.0  2.870000e+04
# 791  100.0  92.0  1.720000e+04
# 792  100.0  93.0  1.560000e+04
# 793  100.0  94.0  3.800000e+04
# 794  100.0  95.0  3.120000e+04
# 795  100.0  96.0  2.260000e+04
# 796  100.0  97.0  1.470000e+04
# 797  100.0  98.0  1.000000e+04
# 798  100.0  99.0  9.702000e+05
#
# [9791 rows x 3 columns]
